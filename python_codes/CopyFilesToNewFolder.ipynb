# %%
pwd
# Out:
# '/home/fei/working/other_codes'

# %%
import os
import shutil

originDir = r'/home/fei/Desktop/data558'
destinationDir = r'/home/fei/Desktop'

count = 0
for root, dirs, files in os.walk(originDir):
    for filename in files:
        path_file = os.path.join(root, filename)
#         base, extension = os.path.splitext(path_file)
#         if ("checkpoint" not in base) & (extension in [".ipynb", ".csv"]):
#             if os.path.exists(destinationDir + "\\" + base[base.rfind('\\')+1:] + extension):
#             # check whether the file to be copied already exists in the destination file
#                 print '%s already exists' %path_file
#                 count += 1
#             else:
#                 shutil.copy2(path_file, destinationDir) 
# print "Number of Duplicated Files: ", count
# Out:
# /home/fei/Desktop/data558/AWS_intro.pdf
# /home/fei/Desktop/data558/syllabus_data558_spring2017.pdf
# /home/fei/Desktop/data558/importance_initialization_momentum_deep_learning.pdf
# /home/fei/Desktop/data558/extract_feature.py
# /home/fei/Desktop/data558/convolutional neural net.pdf
# /home/fei/Desktop/data558/kaggle.ipynb
# /home/fei/Desktop/data558/kaggle_data.zip
# /home/fei/Desktop/data558/8/lab8.ipynb
# /home/fei/Desktop/data558/8/data/motorbike_val.txt
# /home/fei/Desktop/data558/8/data/person_train.txt
# /home/fei/Desktop/data558/8/data/car_train_fv.mat
# /home/fei/Desktop/data558/8/data/aeroplane_val_vlad.mat
# /home/fei/Desktop/data558/8/data/car_train_bovw.mat
# /home/fei/Desktop/data558/8/data/motorbike_val_fv.mat
# /home/fei/Desktop/data558/8/data/horse_val.txt
# /home/fei/Desktop/data558/8/data/background_train_vlad.mat
# /home/fei/Desktop/data558/8/data/aeroplane_val_bovw.mat
# /home/fei/Desktop/data558/8/data/person_val_bovw.mat
# ...
